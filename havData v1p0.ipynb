# %% [markdown]
# # This is a temproary method to analyse Havana Test bringup

# %%
def Multiple_param():
    parameters = ['CHECK IDD','CHECK TMP_AREG_TRIM_CODE', 'CHECK GXOFFSET','CHECK GYOFFSET','CHECK GZOFFSET','CHECK AXOUTPUT','CHECK AYOUTPUT','CHECK AZOUTPUT','CHECK GDRIVEFREQ','CHECK COMM','CHECK IDD','CHECK AXSELFTEST','CHECK AYSELFTEST','CHECK AZSELFTEST',]
    #parameters = ['CHECK GYROBIASAVSS','CHECK ABIASGND','CHECK BIAS_GND','CHECK TSENSEAVSS','TRIM CTATCURRENT','CHECK MINIBG_CTAT_TRIM_D2A_2C_CODE','TRIM PTATCURRENT','CHECK MINIBG_PTAT_TRIM_D2A_CODE','TRIM VREFBG','CHECK MINIBGCODE','TRIM MBCORE_IVBGR','CHECK MBCORE_VBGR_TRIM_D2A_SM_CODE','TRIM VREFVOLTAGE','CHECK DREG_VREF_TRIM_CODE','TRIM DVDD','CHECK DVDDCODE','TRIM RCOSCAREG','CHECK RCOSC_AREG_TRIM_D2A_CODE','TRIM RCOSCRBIASCURRENT','CHECK RCOSC_R_TRIM_D2A_CODE','TRIM RCOSCFREQ','CHECK INTOSCCODE','TRIM LOWPOWEROSC','CHECK WUOSC_FREQ_TRIM_D2A_CODE','CHECK GYRO_MODE','TRIM GYRO_BIAS_AREG','CHECK GYRO_AVDDCODE','TRIM GYRO_BIAS_AREG_CP25V','CHECK GYRO_BIAS_AREG_CP25V_TRIM_D2A_CODE','TRIM GYRO_BIAS_BG','CHECK GYRO_BIAS_BG_TRIM_D2A_CODE','TRIM ACC_CP_REG','CHECK ACCEL_AREG_CP_TRIM_D2A_CODE','TRIM AVDDACCEL1P5V','CHECK ACCEL_AREG_TRIM_D2A_CODE','TRIM TSENSEAVDD','CHECK TMP_AREG_TRIM_CODE','TRIM PADS_TP_AREG','TRIM AXBIAS','TRIM AYBIAS','TRIM AZBIAS','TRIM AXPTATBIAS','TRIM AYPTATBIAS','TRIM AZPTATBIAS','TRIM MBCORERESISTANCEMEASUREMENT','TRIM TIMECONSTANTRCTAUCRTMOM','TRIM TIMECONSTANTRCTAUVPMOM','TRIM CAPACITANCECRTMOM','TRIM CAPACITANCEVPMOM','TRIM ADCRC','CHECK STUPDRIVEAMP1PRE','CHECK STUPDRIVEAMP2PRE','TRIM STUPDRIVEAMP1','TRIM OPTPHSHIFTBLIND','CHECK INTOSCCODE','CHECK GDRIVEFREQ','CHECK GYRO_PLL_VCO_TRIM_D2A_CODE','TRIM GYROPLLDIV','CHECK PLLDIVCODE','SET PLLRESYNC','CHECK CP25RDIV','CHECK GDC2VDCP','CHECK GDC2VDCN','CHECK VPMOMCAPCORRECTIONFACTOR','CHECK GDRIVEFREQ','CHECK GYRO_DRV_AGC_AMP_TRIM_D2A_CODE','CHECK GYRO_DC2V_GAIN_TRIM_D2A_CODE','SET GDRIVEGAP','CHECK GYRO_DRV_AGC_AMP_TRIM_D2A_CODE','CHECK GYRO_DC2V_GAIN_TRIM_D2A_CODE','TRIM GDRIVE','CHECK GYRO_DRV_AGC_AMP_TRIM_D2A_CODE','CHECK GYRO_DC2V_GAIN_TRIM_D2A_CODE','CHECK GDRIVEAMPL','CHECK GDRIVEVOLPEAK','CHECK GDRIVE2NDHARMONIC','CHECK GDRIVE3RDHARMONIC','TRIM GXFEEDTHROUGHQUAD','TRIM GYFEEDTHROUGHQUAD','TRIM GZFEEDTHROUGHQUAD']
    #parameters = ['CHECK GYROBIASAVSS','CHECK ABIASGND','CHECK BIAS_GND','CHECK TSENSEAVSS','CHECK GYROBIASAVSS','CHECK ABIASGND','CHECK BIAS_GND','CHECK TSENSEAVSS']
    # Plot Parameter
    for currentParam in parameters:
        y = ab1[currentParam] # ,fontweight = 'bold']
        x = np.arange(0,100,1)
        plt.figure(currentParam)
        plt.plot(x,y)
        plt.suptitle(currentParam)
        #full_path = os.path.join('Y:\Product Development\HAVANA\A1A1\Char data\Test repeatability\02282017\Plots\', currentParam+ '.jpg')
        #plt.savefig( currentParam+'.jpg')
        plt.show()

# %%
def Single_param():
    parameter = ['CHECK IDD']#,'CHECK TMP_AREG_TRIM_CODE', 'CHECK GXOFFSET','CHECK GYOFFSET','CHECK GZOFFSET','CHECK AXOUTPUT','CHECK AYOUTPUT','CHECK AZOUTPUT','CHECK GDRIVEFREQ','CHECK COMM','CHECK IDD','CHECK AXSELFTEST','CHECK AYSELFTEST','CHECK AZSELFTEST',]
    #parameters = ['CHECK GYROBIASAVSS','CHECK ABIASGND','CHECK BIAS_GND','CHECK TSENSEAVSS','TRIM CTATCURRENT','CHECK MINIBG_CTAT_TRIM_D2A_2C_CODE','TRIM PTATCURRENT','CHECK MINIBG_PTAT_TRIM_D2A_CODE','TRIM VREFBG','CHECK MINIBGCODE','TRIM MBCORE_IVBGR','CHECK MBCORE_VBGR_TRIM_D2A_SM_CODE','TRIM VREFVOLTAGE','CHECK DREG_VREF_TRIM_CODE','TRIM DVDD','CHECK DVDDCODE','TRIM RCOSCAREG','CHECK RCOSC_AREG_TRIM_D2A_CODE','TRIM RCOSCRBIASCURRENT','CHECK RCOSC_R_TRIM_D2A_CODE','TRIM RCOSCFREQ','CHECK INTOSCCODE','TRIM LOWPOWEROSC','CHECK WUOSC_FREQ_TRIM_D2A_CODE','CHECK GYRO_MODE','TRIM GYRO_BIAS_AREG','CHECK GYRO_AVDDCODE','TRIM GYRO_BIAS_AREG_CP25V','CHECK GYRO_BIAS_AREG_CP25V_TRIM_D2A_CODE','TRIM GYRO_BIAS_BG','CHECK GYRO_BIAS_BG_TRIM_D2A_CODE','TRIM ACC_CP_REG','CHECK ACCEL_AREG_CP_TRIM_D2A_CODE','TRIM AVDDACCEL1P5V','CHECK ACCEL_AREG_TRIM_D2A_CODE','TRIM TSENSEAVDD','CHECK TMP_AREG_TRIM_CODE','TRIM PADS_TP_AREG','TRIM AXBIAS','TRIM AYBIAS','TRIM AZBIAS','TRIM AXPTATBIAS','TRIM AYPTATBIAS','TRIM AZPTATBIAS','TRIM MBCORERESISTANCEMEASUREMENT','TRIM TIMECONSTANTRCTAUCRTMOM','TRIM TIMECONSTANTRCTAUVPMOM','TRIM CAPACITANCECRTMOM','TRIM CAPACITANCEVPMOM','TRIM ADCRC','CHECK STUPDRIVEAMP1PRE','CHECK STUPDRIVEAMP2PRE','TRIM STUPDRIVEAMP1','TRIM OPTPHSHIFTBLIND','CHECK INTOSCCODE','CHECK GDRIVEFREQ','CHECK GYRO_PLL_VCO_TRIM_D2A_CODE','TRIM GYROPLLDIV','CHECK PLLDIVCODE','SET PLLRESYNC','CHECK CP25RDIV','CHECK GDC2VDCP','CHECK GDC2VDCN','CHECK VPMOMCAPCORRECTIONFACTOR','CHECK GDRIVEFREQ','CHECK GYRO_DRV_AGC_AMP_TRIM_D2A_CODE','CHECK GYRO_DC2V_GAIN_TRIM_D2A_CODE','SET GDRIVEGAP','CHECK GYRO_DRV_AGC_AMP_TRIM_D2A_CODE','CHECK GYRO_DC2V_GAIN_TRIM_D2A_CODE','TRIM GDRIVE','CHECK GYRO_DRV_AGC_AMP_TRIM_D2A_CODE','CHECK GYRO_DC2V_GAIN_TRIM_D2A_CODE','CHECK GDRIVEAMPL','CHECK GDRIVEVOLPEAK','CHECK GDRIVE2NDHARMONIC','CHECK GDRIVE3RDHARMONIC','TRIM GXFEEDTHROUGHQUAD','TRIM GYFEEDTHROUGHQUAD','TRIM GZFEEDTHROUGHQUAD']
    #parameters = ['CHECK GYROBIASAVSS','CHECK ABIASGND','CHECK BIAS_GND','CHECK TSENSEAVSS','CHECK GYROBIASAVSS','CHECK ABIASGND','CHECK BIAS_GND','CHECK TSENSEAVSS']
    # Plot Parameter
    for currentParam in parameter:
        y = ab1[currentParam] # ,fontweight = 'bold']
        x = np.arange(0,100,1)
        plt.figure(currentParam)
        plt.plot(x,y)
        plt.suptitle(currentParam)
        plt.legend()
        #plt.savefig( currentParam+'.jpg')
        plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os.path
# %matplotlib inline

location = r'Y:\Product Development\HAVANA\A1A1\Char data\Test repeatability\02282017\havData.xlsx'
df = pd.read_excel(location, sheetname = 'Sheet1', header = 0, index_col =0 )
df.head()
#print (df.head()) 
ab = pd.pivot_table(df,index=["SWEEP LOOP","Socket"])
ab1 = ab.unstack(level = -1)
parameter = ['CHECK GXOFFSET']
#Multiple_param()
Single_param()# = r'CHECK IDD')
# Out:
# C:\Users\sbharadwaj\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
